# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.manifold import TSNE
import caffe
import math
import h5py
import random
caffe.set_mode_gpu()

def loadStockH5(fname):
    with h5py.File(fname, 'r') as f:   
        X = f['data'][:]
        y = f['label'][:] 
        y_ = f['realy'][:]
    return np.array(X).astype(np.float32), \
            np.array(y).astype(np.float32).reshape(len(y), 1, 1, 1), \
            np.array(y_).astype(np.float32)

# %matplotlib inline

# %%
datas, _, _ = loadStockH5("./caffe/data_1.h5")
print datas
gpu = 0

PRETRAINED_FILE = "m_%d_iter_17100.caffemodel" % gpu

dim_n = 1024
def forward(net, d, mask=dim_n):
    mask = int(mask)
    print mask,
    data = d.copy()
    #mean = data[0:mask].mean()
    #mean = data.mean()
    #print mean
    data = (data - data[mask-1]*0.999) * 1. * 255
    #data = (data - mean) * 1. * 255
    #data[mask:] = 0
    data[mask:] = data[mask]
    """
    for i in range(mask, data.shape[-1]):
        data.shape = (1, dim_n, 1, 1)
        net.blobs["indata"].data[...] = data
        net.forward()
        out = net.blobs["sigmoid_2"].data
        out.shape = (dim_n)
        data.shape = dim_n
        per = (out[i] - out[i-1]) / out[i-1]
        data[i:] = data[i-1] * per + data[i-1]
    """
    data.shape = (1, dim_n, 1, 1)
    net.blobs["indata"].data[...] = data
    net.forward()
    out = net.blobs["sigmoid_2"].data
    print "forward V2"
    #print net.blobs["drop2_1"].data
    #print out
    out.shape = (dim_n)
    return out.copy()
# Out:
# [ 655850.  655930.  655955. ...,  560145.  560050.  559940.]

# %%
def predict(deploy, model, split_per=0.8, i=-1):
    net = caffe.Net(deploy, model, caffe.TEST)
    if i < 0:
        i = random.randint(0, datas.shape[-1]-dim_n-1)
    d = datas[i:i+dim_n] / 10000
    split_n = int(split_per * dim_n)
    #d = np.zeros(dim_n)
    out1 = forward(net, d, split_n)
    del net
    print "finish", i
    fig = plt.figure(figsize=(12, 8))
    tmp = d[0:split_n]
    pridata = (d-tmp.min()) / (tmp.max()-tmp.min() + 0.00000001)
    plt.plot(range(dim_n), pridata, '-')
    plt.plot(range(dim_n), out1, '-')
    plt.plot([split_n,split_n],[0,1], color ='red', linewidth=2, linestyle="--")
    plt.legend(['0', '1', '2', '3', '4', '5'])
    plt.grid()
    plt.show()

# %%
predict("deploy_%d.prototxt" % gpu, PRETRAINED_FILE, split_per=0.99)
# Out:
# 1013 forward V2
# [[ 18.44718933  18.95690918  17.17094421 ...,  -6.2878418   -6.54270172
#    -7.30922699]]
# [[ 0.66388309  0.66071296  0.67112941 ...,  0.43050969  0.42140308
#    0.42696393]]
# finish 348296

# %%
index = random.randint(0, datas.shape[-1]-dim_n-1)
for j in range(80, 100):
    predict("deploy_%d.prototxt" % gpu, PRETRAINED_FILE, split_per=j*1.0/100, i=index)
# Out:
# 819
# [ -5.01646042  -5.01646042  -1.44647598 ...,  15.19666481  15.13283539
#   15.09232998]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 829
# [ -5.20614624  -5.20614624  -1.6361618  ...,  16.21960449  16.15147781
#   16.10824585]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 839
# [ -5.38902283  -5.38902283  -1.81903839 ...,  14.90673065  14.84411907
#   14.80438614]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 849
# [ -5.57870865  -5.57870865  -2.00872421 ...,  16.8038578   16.73327827
#   16.68848991]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 860
# [ -5.8199501   -5.8199501   -2.24996567 ...,  19.47967529  19.39785576
#   19.34593391]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 870
# [ -6.03395462  -6.03395462  -2.46397018 ...,  18.5448494   18.46695709
#   18.41752815]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 880
# [ -6.24893188  -6.24893188  -2.67894745 ...,  18.73546982  18.65677643
#   18.60683823]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 890
# [ -6.46390915  -6.46390915  -2.89392471 ...,  19.04138947  18.96141052
#   18.91065788]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 901
# [ -6.69445038  -6.69445038  -3.12446594 ...,  17.41422462  17.34108162
#   17.29466629]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 911
# [ -6.85787201  -6.85787201  -3.28788757 ...,  14.71023655  14.6484499
#   14.60924053]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 921
# [ -7.01934814  -7.01934814  -3.44936371 ...,  13.77334404  13.71549225
#   13.67878056]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 931
# [ -7.18471527  -7.18471527  -3.61473083 ...,  16.0984211   16.03080368
#   15.98789501]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 942
# [ -7.37342834  -7.37342834  -3.80344391 ...,  14.83056927  14.76827717
#   14.72874737]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 952
# [ -7.54560471  -7.54560471  -3.97562027 ...,  12.85765457  12.80364895
#   12.76937771]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 962
# [-7.6350975  -7.6350975  -4.06511307 ...,  3.34428716  3.33024025
#   3.32132626]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 972
# [-7.67498016 -7.67498016 -4.10499573 ...,  5.67755508  5.65370798
#   5.63857508]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 983
# [-7.74599075 -7.74599075 -4.17600632 ...,  7.18198395  7.1518178
#   7.13267469]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 993 [-7.80630112 -7.80630112 -4.23631668 ...,  5.75148487  5.72732735
#   5.71199703]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish
#  1253074
# 1003 [-7.89482117 -7.89482117 -4.32483673 ...,  3.98898077  3.97222614
#   3.96159387]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
# 1013 [-7.92303085 -7.92303085 -4.35304642 ...,  3.55352569  3.53859997
#   3.52912831]
# [ 0.49499518  0.49247435  0.49456045 ...,  0.50531906  0.5031966
#   0.50184971]
# finish 1253074
